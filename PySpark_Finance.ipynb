# %% [markdown]
# <a href="https://colab.research.google.com/github/tatianaespinola/conjunto-de-dados-de-transacoes-financeiras-limpeza-e-breve-analise/blob/main/PySpark_Finance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalar Java e Spark
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null

# Define Spark version and download URL
spark_version = "spark-3.1.2"
hadoop_version = "hadoop2.7"
spark_file = f"{spark_version}-bin-{hadoop_version}.tgz"
spark_url = f"https://archive.apache.org/dist/spark/{spark_version}/{spark_file}"

# Download Spark
# !wget -q {spark_url}

# Check if download was successful and extract
import os
if os.path.exists(spark_file):
    print(f"{spark_file} downloaded successfully. Extracting...")
    # !tar xf {spark_file}
    print("Extraction complete.")
else:
    print(f"Error: {spark_file} not downloaded.")


# Configurar variáveis
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-{hadoop_version}"

# Instalar findspark e pyspark e inicializar findspark
# !pip install -q findspark pyspark
import findspark
findspark.init()
# Out:
# spark-3.1.2-bin-hadoop2.7.tgz downloaded successfully. Extracting...
# Extraction complete.

# %%
import findspark
findspark.init()
from pyspark.sql.functions import when, col, count, isnan, regexp_replace, sum
from pyspark.sql import functions as F
from pyspark.sql import SparkSession
from functools import reduce

spark = SparkSession.builder.master("local[*]").getOrCreate()

# %%
# Criação de um DataFrame
df = spark.read.csv("/content/transactions_data.csv", header=True, inferSchema = True)

# %%
# Visualização do esquema do DataFrame incluindo nome das colunas e datatype
df.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- date: string (nullable = true)
#  |-- client_id: integer (nullable = true)
#  |-- card_id: integer (nullable = true)
#  |-- amount: string (nullable = true)
#  |-- use_chip: string (nullable = true)
#  |-- merchant_id: integer (nullable = true)
#  |-- merchant_city: string (nullable = true)
#  |-- merchant_state: string (nullable = true)
#  |-- zip: double (nullable = true)
#  |-- mcc: integer (nullable = true)
#  |-- errors: string (nullable = true)

# %%
# Visualização de dados do DataFrame
df.show()
# Out:
# +-------+-------------------+---------+-------+-------+------------------+-----------+---------------+--------------+-------+----+------+
# |     id|               date|client_id|card_id| amount|          use_chip|merchant_id|  merchant_city|merchant_state|    zip| mcc|errors|
# +-------+-------------------+---------+-------+-------+------------------+-----------+---------------+--------------+-------+----+------+
# |7475327|2010-01-01 00:01:00|     1556|   2972|$-77.00| Swipe Transaction|      59935|         Beulah|            ND|58523.0|5499|  null|
# |7475328|2010-01-01 00:02:00|      561|   4575| $14.57| Swipe Transaction|      67570|     Bettendorf|            IA|52722.0|5311|  null|
# |7475329|2010-01-01 00:02:00|     1129|    102| $80.00| Swipe Transaction|      27092|          Vista|            CA|92084.0|4829|  null|
# |7475331|2010-01-01 00:05:00|      430|   2860|$200.00| Swipe Transaction|      27092|    Crown Point|            IN|46307.0|4829|  null|
# |7475332|2010-01-01 00:06:00|      848|   3915| $46.41| Swipe Transaction|      13051|        Harwood|            MD|20776.0|5813|  null|
# |7475333|2010-01-01 00:07:00|     1807|    165|  $4.81| Swipe Transaction|      20519|          Bronx|            NY|10464.0|5942|  null|
# |7475334|2010-01-01 00:09:00|     1556|   2972| $77.00| Swipe Transaction|      59935|         Beulah|            ND|58523.0|5499|  null|
# |7475335|2010-01-01 00:14:00|     1684|   2140| $26.46|Online Transaction|      39021|         ONLINE|          null|   null|4784|  null|
# |7475336|2010-01-01 00:21:00|      335|   5131|$261.58|Online Transaction|      50292|         ONLINE|          null|   null|7801|  null|
# |7475337|2010-01-01 00:21:00|      351|   1112| $10.74| Swipe Transaction|       3864|       Flushing|            NY|11355.0|5813|  null|
# |7475338|2010-01-01 00:23:00|      554|   3912|  $3.51| Swipe Transaction|      67570|       Pearland|            TX|77581.0|5311|  null|
# |7475339|2010-01-01 00:23:00|      605|   5061|  $2.58| Swipe Transaction|      75781|       Brooklyn|            NY|11210.0|5411|  null|
# |7475340|2010-01-01 00:26:00|     1556|   2972| $39.63| Swipe Transaction|      59935|         Beulah|            ND|58523.0|5499|  null|
# |7475341|2010-01-01 00:27:00|     1797|   1127| $43.33| Swipe Transaction|      33326|        Kahului|            HI|96732.0|4121|  null|
# |7475342|2010-01-01 00:30:00|      114|   3398| $49.42| Swipe Transaction|      61195|North Hollywood|            CA|91606.0|5541|  null|
# |7475343|2010-01-01 00:31:00|     1634|   2464|  $1.09| Swipe Transaction|      20519|     San Benito|            TX|78586.0|5942|  null|
# |7475344|2010-01-01 00:32:00|      646|   2093| $73.79| Swipe Transaction|       1636|           Erie|            PA|16511.0|7538|  null|
# |7475345|2010-01-01 00:32:00|     1129|   5492|$100.00| Swipe Transaction|      27092|          Vista|            CA|92084.0|4829|  null|
# |7475346|2010-01-01 00:34:00|      394|   4717| $26.04|Online Transaction|      39021|         ONLINE|          null|   null|4784|  null|
# |7475347|2010-01-01 00:36:00|      114|   3398|$-64.00| Swipe Transaction|      61195|North Hollywood|            CA|91606.0|5541|  null|
# +-------+-------------------+---------+-------+-------+------------------+-----------+---------------+--------------+-------+----+------+
# only showing top 20 rows

# %%
# Contagem do número de linhas do DataFrame
df.count()
# Out:
# 4999

# %%
# Exclusão de linhas duplicadas e contagem após essa exclusão
df.dropDuplicates().count()
# Out:
# 4999

# %%
# Modificar os dados que estão como ''null'' na coluna 'errors'
df = df.withColumn(
    "errors",
    when(col("errors").isNull(), "Sem erro").otherwise(col("errors"))
)

# %%
df.show()
# Out:
# +-------+-------------------+---------+-------+-------+------------------+-----------+---------------+--------------+-------+----+--------+
# |     id|               date|client_id|card_id| amount|          use_chip|merchant_id|  merchant_city|merchant_state|    zip| mcc|  errors|
# +-------+-------------------+---------+-------+-------+------------------+-----------+---------------+--------------+-------+----+--------+
# |7475327|2010-01-01 00:01:00|     1556|   2972|$-77.00| Swipe Transaction|      59935|         Beulah|            ND|58523.0|5499|Sem erro|
# |7475328|2010-01-01 00:02:00|      561|   4575| $14.57| Swipe Transaction|      67570|     Bettendorf|            IA|52722.0|5311|Sem erro|
# |7475329|2010-01-01 00:02:00|     1129|    102| $80.00| Swipe Transaction|      27092|          Vista|            CA|92084.0|4829|Sem erro|
# |7475331|2010-01-01 00:05:00|      430|   2860|$200.00| Swipe Transaction|      27092|    Crown Point|            IN|46307.0|4829|Sem erro|
# |7475332|2010-01-01 00:06:00|      848|   3915| $46.41| Swipe Transaction|      13051|        Harwood|            MD|20776.0|5813|Sem erro|
# |7475333|2010-01-01 00:07:00|     1807|    165|  $4.81| Swipe Transaction|      20519|          Bronx|            NY|10464.0|5942|Sem erro|
# |7475334|2010-01-01 00:09:00|     1556|   2972| $77.00| Swipe Transaction|      59935|         Beulah|            ND|58523.0|5499|Sem erro|
# |7475335|2010-01-01 00:14:00|     1684|   2140| $26.46|Online Transaction|      39021|         ONLINE|          null|   null|4784|Sem erro|
# |7475336|2010-01-01 00:21:00|      335|   5131|$261.58|Online Transaction|      50292|         ONLINE|          null|   null|7801|Sem erro|
# |7475337|2010-01-01 00:21:00|      351|   1112| $10.74| Swipe Transaction|       3864|       Flushing|            NY|11355.0|5813|Sem erro|
# |7475338|2010-01-01 00:23:00|      554|   3912|  $3.51| Swipe Transaction|      67570|       Pearland|            TX|77581.0|5311|Sem erro|
# |7475339|2010-01-01 00:23:00|      605|   5061|  $2.58| Swipe Transaction|      75781|       Brooklyn|            NY|11210.0|5411|Sem erro|
# |7475340|2010-01-01 00:26:00|     1556|   2972| $39.63| Swipe Transaction|      59935|         Beulah|            ND|58523.0|5499|Sem erro|
# |7475341|2010-01-01 00:27:00|     1797|   1127| $43.33| Swipe Transaction|      33326|        Kahului|            HI|96732.0|4121|Sem erro|
# |7475342|2010-01-01 00:30:00|      114|   3398| $49.42| Swipe Transaction|      61195|North Hollywood|            CA|91606.0|5541|Sem erro|
# |7475343|2010-01-01 00:31:00|     1634|   2464|  $1.09| Swipe Transaction|      20519|     San Benito|            TX|78586.0|5942|Sem erro|
# |7475344|2010-01-01 00:32:00|      646|   2093| $73.79| Swipe Transaction|       1636|           Erie|            PA|16511.0|7538|Sem erro|
# |7475345|2010-01-01 00:32:00|     1129|   5492|$100.00| Swipe Transaction|      27092|          Vista|            CA|92084.0|4829|Sem erro|
# |7475346|2010-01-01 00:34:00|      394|   4717| $26.04|Online Transaction|      39021|         ONLINE|          null|   null|4784|Sem erro|
# |7475347|2010-01-01 00:36:00|      114|   3398|$-64.00| Swipe Transaction|      61195|North Hollywood|            CA|91606.0|5541|Sem erro|
# +-------+-------------------+---------+-------+-------+------------------+-----------+---------------+--------------+-------+----+--------+
# only showing top 20 rows

# %%
#Exclua linhas que tem valores nulos em todas as colunas
df = df.dropna(how="all")

# %%
df.count()
# Out:
# 4999

# %%
from pyspark.sql import functions as F

# Contar valores nulos, vazios ou NaN por coluna
null_counts = df.select([
    count(
        when(
            col(c).isNull() | (col(c) == '') | isnan(c), c
        )
    ).alias(c)
    for c in df.columns
])

# Transpor para formato (coluna, qtd_nulos)
null_counts = null_counts.toPandas().T.reset_index()
null_counts.columns = ['coluna', 'qtd_nulos']

# Ordenar do maior para o menor
null_counts = null_counts.sort_values(by='qtd_nulos', ascending=False)

# Exibir resultado
null_counts
# Out:
#             coluna  qtd_nulos
# 9              zip        644
# 8   merchant_state        635
# 0               id          0
# 1             date          0
# 3          card_id          0
# 2        client_id          0
# 4           amount          0
# 5         use_chip          0
# 7    merchant_city          0
# 6      merchant_id          0
# 10             mcc          0
# 11          errors          0

# %%
df = df.withColumn(
    "merchant_state",
    when((col("merchant_city") == "ONLINE") & col("merchant_state").isNull(), "ONLINE")
    .otherwise(col("merchant_state"))
).withColumn(
    "zip",
    when((col("merchant_city") == "ONLINE") & col("zip").isNull(), "0")
    .otherwise(col("zip"))
)

# %%
df.show()
# Out:
# +-------+-------------------+---------+-------+-------+------------------+-----------+---------------+--------------+-------+----+--------+
# |     id|               date|client_id|card_id| amount|          use_chip|merchant_id|  merchant_city|merchant_state|    zip| mcc|  errors|
# +-------+-------------------+---------+-------+-------+------------------+-----------+---------------+--------------+-------+----+--------+
# |7475327|2010-01-01 00:01:00|     1556|   2972|$-77.00| Swipe Transaction|      59935|         Beulah|            ND|58523.0|5499|Sem erro|
# |7475328|2010-01-01 00:02:00|      561|   4575| $14.57| Swipe Transaction|      67570|     Bettendorf|            IA|52722.0|5311|Sem erro|
# |7475329|2010-01-01 00:02:00|     1129|    102| $80.00| Swipe Transaction|      27092|          Vista|            CA|92084.0|4829|Sem erro|
# |7475331|2010-01-01 00:05:00|      430|   2860|$200.00| Swipe Transaction|      27092|    Crown Point|            IN|46307.0|4829|Sem erro|
# |7475332|2010-01-01 00:06:00|      848|   3915| $46.41| Swipe Transaction|      13051|        Harwood|            MD|20776.0|5813|Sem erro|
# |7475333|2010-01-01 00:07:00|     1807|    165|  $4.81| Swipe Transaction|      20519|          Bronx|            NY|10464.0|5942|Sem erro|
# |7475334|2010-01-01 00:09:00|     1556|   2972| $77.00| Swipe Transaction|      59935|         Beulah|            ND|58523.0|5499|Sem erro|
# |7475335|2010-01-01 00:14:00|     1684|   2140| $26.46|Online Transaction|      39021|         ONLINE|        ONLINE|      0|4784|Sem erro|
# |7475336|2010-01-01 00:21:00|      335|   5131|$261.58|Online Transaction|      50292|         ONLINE|        ONLINE|      0|7801|Sem erro|
# |7475337|2010-01-01 00:21:00|      351|   1112| $10.74| Swipe Transaction|       3864|       Flushing|            NY|11355.0|5813|Sem erro|
# |7475338|2010-01-01 00:23:00|      554|   3912|  $3.51| Swipe Transaction|      67570|       Pearland|            TX|77581.0|5311|Sem erro|
# |7475339|2010-01-01 00:23:00|      605|   5061|  $2.58| Swipe Transaction|      75781|       Brooklyn|            NY|11210.0|5411|Sem erro|
# |7475340|2010-01-01 00:26:00|     1556|   2972| $39.63| Swipe Transaction|      59935|         Beulah|            ND|58523.0|5499|Sem erro|
# |7475341|2010-01-01 00:27:00|     1797|   1127| $43.33| Swipe Transaction|      33326|        Kahului|            HI|96732.0|4121|Sem erro|
# |7475342|2010-01-01 00:30:00|      114|   3398| $49.42| Swipe Transaction|      61195|North Hollywood|            CA|91606.0|5541|Sem erro|
# |7475343|2010-01-01 00:31:00|     1634|   2464|  $1.09| Swipe Transaction|      20519|     San Benito|            TX|78586.0|5942|Sem erro|
# |7475344|2010-01-01 00:32:00|      646|   2093| $73.79| Swipe Transaction|       1636|           Erie|            PA|16511.0|7538|Sem erro|
# |7475345|2010-01-01 00:32:00|     1129|   5492|$100.00| Swipe Transaction|      27092|          Vista|            CA|92084.0|4829|Sem erro|
# |7475346|2010-01-01 00:34:00|      394|   4717| $26.04|Online Transaction|      39021|         ONLINE|        ONLINE|      0|4784|Sem erro|
# |7475347|2010-01-01 00:36:00|      114|   3398|$-64.00| Swipe Transaction|      61195|North Hollywood|            CA|91606.0|5541|Sem erro|
# +-------+-------------------+---------+-------+-------+------------------+-----------+---------------+--------------+-------+----+--------+
# only showing top 20 rows

# %%
# Contar valores nulos, vazios ou NaN por coluna
null_counts = df.select([
    count(
        when(
            col(c).isNull() | (col(c) == '') | isnan(c), c
        )
    ).alias(c)
    for c in df.columns
])

# Transpor para formato (coluna, qtd_nulos)
null_counts = null_counts.toPandas().T.reset_index()
null_counts.columns = ['coluna', 'qtd_nulos']

# Ordenar do maior para o menor
null_counts = null_counts.sort_values(by='qtd_nulos', ascending=False)

# Exibir resultado
null_counts
# Out:
#             coluna  qtd_nulos
# 9              zip          9
# 0               id          0
# 2        client_id          0
# 1             date          0
# 3          card_id          0
# 4           amount          0
# 6      merchant_id          0
# 5         use_chip          0
# 7    merchant_city          0
# 8   merchant_state          0
# 10             mcc          0
# 11          errors          0

# %%
df.filter(
    reduce(lambda a, b: a | b, (col(c).isNull() for c in df.columns))
).show()
# Out:
# +-------+-------------------+---------+-------+------+-----------------+-----------+---------------+------------------+----+----+--------+
# |     id|               date|client_id|card_id|amount|         use_chip|merchant_id|  merchant_city|    merchant_state| zip| mcc|  errors|
# +-------+-------------------+---------+-------+------+-----------------+-----------+---------------+------------------+----+----+--------+
# |7476010|2010-01-01 07:53:00|     1579|   3830| $6.51|Swipe Transaction|      22204|Puerto Vallarta|            Mexico|null|5541|Sem erro|
# |7476549|2010-01-01 10:03:00|      363|   5555| $8.16|Swipe Transaction|      93391|   Vatican City|      Vatican City|null|5812|Sem erro|
# |7476704|2010-01-01 10:37:00|      363|   5555|$11.66|Swipe Transaction|      93391|   Vatican City|      Vatican City|null|5812|Sem erro|
# |7477375|2010-01-01 12:50:00|     1266|   2478| $9.77|Swipe Transaction|      22204|    Guadalajara|            Mexico|null|5541|Sem erro|
# |7477534|2010-01-01 13:19:00|     1266|   2478|$11.32|Swipe Transaction|      75804|    Guadalajara|            Mexico|null|5411|Sem erro|
# |7478204|2010-01-01 16:07:00|      363|   5364|$10.40|Swipe Transaction|      13067|   Vatican City|      Vatican City|null|5411|Sem erro|
# |7479335|2010-01-01 22:35:00|      738|    204|$57.80|Swipe Transaction|        246|  Santo Domingo|Dominican Republic|null|5812|Sem erro|
# |7479985|2010-01-02 07:43:00|     1579|     11| $7.38|Swipe Transaction|       7886|Puerto Vallarta|            Mexico|null|5812|Sem erro|
# |7480670|2010-01-02 10:51:00|      363|   5555|$11.94|Swipe Transaction|      13067|   Vatican City|      Vatican City|null|5411|Sem erro|
# +-------+-------------------+---------+-------+------+-----------------+-----------+---------------+------------------+----+----+--------+

# %%
# Modificar os dados que estão como ''null'' na coluna 'zip'
df = df.withColumn(
    "zip",
    when(col("zip").isNull(), "ZIP não informado").otherwise(col("zip"))
)

# %%
null_counts
# Out:
#             coluna  qtd_nulos
# 9              zip          9
# 0               id          0
# 2        client_id          0
# 1             date          0
# 3          card_id          0
# 4           amount          0
# 6      merchant_id          0
# 5         use_chip          0
# 7    merchant_city          0
# 8   merchant_state          0
# 10             mcc          0
# 11          errors          0

# %%
df = (df
    .withColumnRenamed("zip", "zip_code")
    .withColumnRenamed("mcc", "merchant_category_code")
)

# %%
df.show()
# Out:
# +-------+-------------------+---------+-------+-------+------------------+-----------+---------------+--------------+--------+----------------------+--------+
# |     id|               date|client_id|card_id| amount|          use_chip|merchant_id|  merchant_city|merchant_state|zip_code|merchant_category_code|  errors|
# +-------+-------------------+---------+-------+-------+------------------+-----------+---------------+--------------+--------+----------------------+--------+
# |7475327|2010-01-01 00:01:00|     1556|   2972|$-77.00| Swipe Transaction|      59935|         Beulah|            ND| 58523.0|                  5499|Sem erro|
# |7475328|2010-01-01 00:02:00|      561|   4575| $14.57| Swipe Transaction|      67570|     Bettendorf|            IA| 52722.0|                  5311|Sem erro|
# |7475329|2010-01-01 00:02:00|     1129|    102| $80.00| Swipe Transaction|      27092|          Vista|            CA| 92084.0|                  4829|Sem erro|
# |7475331|2010-01-01 00:05:00|      430|   2860|$200.00| Swipe Transaction|      27092|    Crown Point|            IN| 46307.0|                  4829|Sem erro|
# |7475332|2010-01-01 00:06:00|      848|   3915| $46.41| Swipe Transaction|      13051|        Harwood|            MD| 20776.0|                  5813|Sem erro|
# |7475333|2010-01-01 00:07:00|     1807|    165|  $4.81| Swipe Transaction|      20519|          Bronx|            NY| 10464.0|                  5942|Sem erro|
# |7475334|2010-01-01 00:09:00|     1556|   2972| $77.00| Swipe Transaction|      59935|         Beulah|            ND| 58523.0|                  5499|Sem erro|
# |7475335|2010-01-01 00:14:00|     1684|   2140| $26.46|Online Transaction|      39021|         ONLINE|        ONLINE|       0|                  4784|Sem erro|
# |7475336|2010-01-01 00:21:00|      335|   5131|$261.58|Online Transaction|      50292|         ONLINE|        ONLINE|       0|                  7801|Sem erro|
# |7475337|2010-01-01 00:21:00|      351|   1112| $10.74| Swipe Transaction|       3864|       Flushing|            NY| 11355.0|                  5813|Sem erro|
# |7475338|2010-01-01 00:23:00|      554|   3912|  $3.51| Swipe Transaction|      67570|       Pearland|            TX| 77581.0|                  5311|Sem erro|
# |7475339|2010-01-01 00:23:00|      605|   5061|  $2.58| Swipe Transaction|      75781|       Brooklyn|            NY| 11210.0|                  5411|Sem erro|
# |7475340|2010-01-01 00:26:00|     1556|   2972| $39.63| Swipe Transaction|      59935|         Beulah|            ND| 58523.0|                  5499|Sem erro|
# |7475341|2010-01-01 00:27:00|     1797|   1127| $43.33| Swipe Transaction|      33326|        Kahului|            HI| 96732.0|                  4121|Sem erro|
# |7475342|2010-01-01 00:30:00|      114|   3398| $49.42| Swipe Transaction|      61195|North Hollywood|            CA| 91606.0|                  5541|Sem erro|
# |7475343|2010-01-01 00:31:00|     1634|   2464|  $1.09| Swipe Transaction|      20519|     San Benito|            TX| 78586.0|                  5942|Sem erro|
# |7475344|2010-01-01 00:32:00|      646|   2093| $73.79| Swipe Transaction|       1636|           Erie|            PA| 16511.0|                  7538|Sem erro|
# |7475345|2010-01-01 00:32:00|     1129|   5492|$100.00| Swipe Transaction|      27092|          Vista|            CA| 92084.0|                  4829|Sem erro|
# |7475346|2010-01-01 00:34:00|      394|   4717| $26.04|Online Transaction|      39021|         ONLINE|        ONLINE|       0|                  4784|Sem erro|
# |7475347|2010-01-01 00:36:00|      114|   3398|$-64.00| Swipe Transaction|      61195|North Hollywood|            CA| 91606.0|                  5541|Sem erro|
# +-------+-------------------+---------+-------+-------+------------------+-----------+---------------+--------------+--------+----------------------+--------+
# only showing top 20 rows

# %%
# Clean the 'amount' column by removing '$' and ',' and casting to double
df = df.withColumn("amount", regexp_replace(col("amount"), "[$,]", "").cast("double"))

df.select("amount").show()
# Out:
# +------+
# |amount|
# +------+
# | -77.0|
# | 14.57|
# |  80.0|
# | 200.0|
# | 46.41|
# |  4.81|
# |  77.0|
# | 26.46|
# |261.58|
# | 10.74|
# |  3.51|
# |  2.58|
# | 39.63|
# | 43.33|
# | 49.42|
# |  1.09|
# | 73.79|
# | 100.0|
# | 26.04|
# | -64.0|
# +------+
# only showing top 20 rows

# %%
# Calculate the total amount spent per client
total_gasto_por_cliente = df.groupBy("client_id").agg(
    sum("amount").alias("total_gasto_por_cliente")
)

# Show the result
total_gasto_por_cliente.show()
# Out:
# +---------+-----------------------+
# |client_id|total_gasto_por_cliente|
# +---------+-----------------------+
# |      148|                  75.16|
# |     1591|                  153.0|
# |     1238|                 533.67|
# |     1645|     -3.270000000000005|
# |     1959|                  29.33|
# |     1088|                 212.59|
# |      496|                 172.73|
# |     1127|                 157.29|
# |      858|                 134.02|
# |     1084|     10.629999999999999|
# |      737|     216.09000000000003|
# |     1507|                 116.55|
# |     1896|                 207.49|
# |      623|                 124.37|
# |     1618|                  146.2|
# |     1352|                 219.29|
# |     1903|                 155.96|
# |     1699|                 271.99|
# |      137|                 329.58|
# |      580|                 200.65|
# +---------+-----------------------+
# only showing top 20 rows

# %%
total_gasto_por_cliente.write.parquet("/content/total_gasto_por_cliente.parquet")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# /tmp/ipython-input-662434606.py in <cell line: 0>()
# ----> 1 total_gasto_por_cliente.write.parquet("/content/total_gasto_por_cliente.parquet")
#
# /content/spark-3.1.2-bin-hadoop2.7/python/pyspark/sql/readwriter.py in parquet(self, path, mode, partitionBy, compression)
#    1248             self.partitionBy(partitionBy)
#    1249         self._set_opts(compression=compression)
# -> 1250         self._jwrite.parquet(path)
#    1251
#    1252     def text(self, path, compression=None, lineSep=None):
#
# /content/spark-3.1.2-bin-hadoop2.7/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /content/spark-3.1.2-bin-hadoop2.7/python/pyspark/sql/utils.py in deco(*a, **kw)
#     115                 # Hide where the exception came from that shows a non-Pythonic
#     116                 # JVM exception message.
# --> 117                 raise converted from None
#     118             else:
#     119                 raise
#
# AnalysisException: path file:/content/total_gasto_por_cliente.parquet already exists.

# %%
#Total gasto por categoria

total_gasto_por_categoria= df.groupBy("use_chip").agg(
    sum("amount").alias("total_gasto_por_categoria")
)

# Show the result
total_gasto_por_categoria.show()

# %%
total_gasto_por_categoria.write.parquet("/content/total_gasto_por_categoria.parquet")

# %%
#Salvar dados no formato parquet
df.write.parquet("/content/transactions_dados_tratados.parquet")
